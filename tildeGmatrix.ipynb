# %% [markdown]
# # Explicit LaTeX expressions for tilde G
#
# Here is the raw LaTeX code for the non-zero elements of $\tilde{G}$ used in the proof of Theorem 1(Appendix A). You can directly copy this into your manuscript.
#
# ```latex
# \begin{align*}
# &\{1,7\}\rightarrow\frac{1}{6},\{1,13\}\rightarrow\frac{1}{6},\{1,16\}\rightarrow\frac{1}{3},\{1,19\}\rightarrow\frac{1}{6},\{1,25\}\rightarrow\frac{1}{6},\{1,28\}\rightarrow\frac{1}{3},\{1,55\}\rightarrow\frac{1}{3},\{1,61\}\rightarrow\frac{1}{3},\\
# &\{1,64\}\rightarrow\frac{2}{3},\{2,5\}\rightarrow-\frac{1}{3},\{2,8\}\rightarrow-\frac{1}{6},\{2,14\}\rightarrow-\frac{1}{6},\{2,17\}\rightarrow-\frac{1}{3},\{2,20\}\rightarrow-\frac{1}{6},\{2,26\}\rightarrow-\frac{1}{6},\{2,53\}\rightarrow-\frac{2}{3},\\
# &\{2,56\}\rightarrow-\frac{1}{3},\{2,62\}\rightarrow-\frac{1}{3},\{3,3\}\rightarrow-\frac{1}{3},\{3,9\}\rightarrow-\frac{1}{3},\{3,12\}\rightarrow-\frac{2}{3},\{3,39\}\rightarrow-\frac{1}{6},\{3,45\}\rightarrow-\frac{1}{6},\{3,48\}\rightarrow-\frac{1}{3},\\
# &\{3,51\}\rightarrow-\frac{1}{6},\{3,57\}\rightarrow-\frac{1}{6},\{3,60\}\rightarrow-\frac{1}{3},\{4,1\}\rightarrow\frac{2}{3},\{4,4\}\rightarrow\frac{1}{3},\{4,10\}\rightarrow\frac{1}{3},\{4,37\}\rightarrow\frac{1}{3},\{4,40\}\rightarrow\frac{1}{6},\\
# &\{4,46\}\rightarrow\frac{1}{6},\{4,49\}\rightarrow\frac{1}{3},\{4,52\}\rightarrow\frac{1}{6},\{4,58\}\rightarrow\frac{1}{6},\{5,7\}\rightarrow-\frac{1}{2},\{5,13\}\rightarrow\frac{1}{2},\{5,19\}\rightarrow\frac{1}{2},\{5,25\}\rightarrow-\frac{1}{2},\\
# &\{6,8\}\rightarrow-\frac{1}{2},\{6,14\}\rightarrow\frac{1}{2},\{6,20\}\rightarrow\frac{1}{2},\{6,26\}\rightarrow-\frac{1}{2},\{7,39\}\rightarrow-\frac{1}{2},\{7,45\}\rightarrow\frac{1}{2},\{7,51\}\rightarrow\frac{1}{2},\{7,57\}\rightarrow-\frac{1}{2},\\
# &\{8,40\}\rightarrow-\frac{1}{2},\{8,46\}\rightarrow\frac{1}{2},\{8,52\}\rightarrow\frac{1}{2},\{8,58\}\rightarrow-\frac{1}{2},\\
# &\{9,7\}\rightarrow\frac{i}{2\sqrt{3}},\{9,13\}\rightarrow\frac{i}{2\sqrt{3}},\{9,16\}\rightarrow\frac{i}{\sqrt{3}},\{9,19\}\rightarrow-\frac{i}{2\sqrt{3}},\{9,25\}\rightarrow-\frac{i}{2\sqrt{3}},\\
# &\{9,28\}\rightarrow-\frac{i}{\sqrt{3}},\{10,5\}\rightarrow-\frac{i}{\sqrt{3}},\{10,8\}\rightarrow-\frac{i}{2\sqrt{3}},\{10,14\}\rightarrow-\frac{i}{2\sqrt{3}},\{10,17\}\rightarrow\frac{i}{\sqrt{3}},\\
# &\{10,20\}\rightarrow\frac{i}{2\sqrt{3}},\{10,26\}\rightarrow\frac{i}{2\sqrt{3}},\{11,39\}\rightarrow\frac{i}{2\sqrt{3}},\{11,45\}\rightarrow\frac{i}{2\sqrt{3}},\{11,48\}\rightarrow\frac{i}{\sqrt{3}},\\
# &\{11,51\}\rightarrow-\frac{i}{2\sqrt{3}},\{11,57\}\rightarrow-\frac{i}{2\sqrt{3}},\{11,60\}\rightarrow-\frac{i}{\sqrt{3}},\{12,37\}\rightarrow-\frac{i}{\sqrt{3}},\{12,40\}\rightarrow-\frac{i}{2\sqrt{3}},\\
# &\{12,46\}\rightarrow-\frac{i}{2\sqrt{3}},\{12,49\}\rightarrow\frac{i}{\sqrt{3}},\{12,52\}\rightarrow\frac{i}{2\sqrt{3}},\{12,58\}\rightarrow\frac{i}{2\sqrt{3}},\{13,7\}\rightarrow\frac{i}{2\sqrt{3}},\\
# &\{13,13\}\rightarrow-\frac{i}{2\sqrt{3}},\{13,19\}\rightarrow\frac{i}{2\sqrt{3}},\{13,25\}\rightarrow-\frac{i}{2\sqrt{3}},\{13,55\}\rightarrow\frac{i}{\sqrt{3}},\{13,61\}\rightarrow-\frac{i}{\sqrt{3}},\\
# &\{14,8\}\rightarrow\frac{i}{2\sqrt{3}},\{14,14\}\rightarrow-\frac{i}{2\sqrt{3}},\{14,20\}\rightarrow\frac{i}{2\sqrt{3}},\{14,26\}\rightarrow-\frac{i}{2\sqrt{3}},\{14,56\}\rightarrow\frac{i}{\sqrt{3}},\\
# &\{14,62\}\rightarrow-\frac{i}{\sqrt{3}},\{15,3\}\rightarrow-\frac{i}{\sqrt{3}},\{15,9\}\rightarrow\frac{i}{\sqrt{3}},\{15,39\}\rightarrow-\frac{i}{2\sqrt{3}},\{15,45\}\rightarrow\frac{i}{2\sqrt{3}},\\
# &\{15,51\}\rightarrow-\frac{i}{2\sqrt{3}},\{15,57\}\rightarrow\frac{i}{2\sqrt{3}},\{16,4\}\rightarrow-\frac{i}{\sqrt{3}},\{16,10\}\rightarrow\frac{i}{\sqrt{3}},\{16,40\}\rightarrow-\frac{i}{2\sqrt{3}},\\
# &\{16,46\}\rightarrow\frac{i}{2\sqrt{3}},\{16,52\}\rightarrow-\frac{i}{2\sqrt{3}},\{16,58\}\rightarrow\frac{i}{2\sqrt{3}},\{17,15\}\rightarrow\frac{1}{\sqrt{6}},\{17,27\}\rightarrow\frac{1}{\sqrt{6}},\\
# &\{17,63\}\rightarrow\sqrt{\frac{2}{3}},\{18,7\}\rightarrow-\frac{1}{3\sqrt{2}},\{18,13\}\rightarrow-\frac{1}{3\sqrt{2}},\{18,16\}\rightarrow\frac{1}{3\sqrt{2}},\{18,19\}\rightarrow-\frac{1}{3\sqrt{2}},\{18,25\}\rightarrow-\frac{1}{3\sqrt{2}},\\
# &\{18,28\}\rightarrow\frac{1}{3\sqrt{2}},\{18,55\}\rightarrow-\frac{\sqrt{2}}{3},\{18,61\}\rightarrow-\frac{\sqrt{2}}{3},\{18,64\}\rightarrow\frac{\sqrt{2}}{3},\{19,11\}\rightarrow-\sqrt{\frac{2}{3}},\{19,47\}\rightarrow-\frac{1}{\sqrt{6}},\\
# &\{19,59\}\rightarrow-\frac{1}{\sqrt{6}},\{20,3\}\rightarrow\frac{\sqrt{2}}{3},\{20,9\}\rightarrow\frac{\sqrt{2}}{3},\{20,12\}\rightarrow-\frac{\sqrt{2}}{3},\{20,39\}\rightarrow\frac{1}{3\sqrt{2}},\{20,45\}\rightarrow\frac{1}{3\sqrt{2}},\\
# &\{20,48\}\rightarrow-\frac{1}{3\sqrt{2}},\{20,51\}\rightarrow\frac{1}{3\sqrt{2}},\{20,57\}\rightarrow\frac{1}{3\sqrt{2}},\{20,60\}\rightarrow-\frac{1}{3\sqrt{2}},\{21,5\}\rightarrow\frac{1}{3\sqrt{2}},\{21,8\}\rightarrow-\frac{1}{3\sqrt{2}},\\
# &\{21,14\}\rightarrow-\frac{1}{3\sqrt{2}},\{21,17\}\rightarrow\frac{1}{3\sqrt{2}},\{21,20\}\rightarrow-\frac{1}{3\sqrt{2}},\{21,26\}\rightarrow-\frac{1}{3\sqrt{2}},\{21,53\}\rightarrow\frac{\sqrt{2}}{3},\{21,56\}\rightarrow-\frac{\sqrt{2}}{3},\\
# &\{21,62\}\rightarrow-\frac{\sqrt{2}}{3},\{22,6\}\rightarrow\frac{1}{\sqrt{6}},\{22,18\}\rightarrow\frac{1}{\sqrt{6}},\{22,54\}\rightarrow\sqrt{\frac{2}{3}},\{23,1\}\rightarrow-\frac{\sqrt{2}}{3},\{23,4\}\rightarrow\frac{\sqrt{2}}{3},\\
# &\{23,10\}\rightarrow\frac{\sqrt{2}}{3},\{23,37\}\rightarrow-\frac{1}{3\sqrt{2}},\{23,40\}\rightarrow\frac{1}{3\sqrt{2}},\{23,46\}\rightarrow\frac{1}{3\sqrt{2}},\{23,49\}\rightarrow-\frac{1}{3\sqrt{2}},\{23,52\}\rightarrow\frac{1}{3\sqrt{2}},\\
# &\{23,58\}\rightarrow\frac{1}{3\sqrt{2}},\{24,2\}\rightarrow-\sqrt{\frac{2}{3}},\{24,38\}\rightarrow-\frac{1}{\sqrt{6}},\{24,50\}\rightarrow-\frac{1}{\sqrt{6}},\{25,15\}\rightarrow\frac{i}{\sqrt{2}},\{25,27\}\rightarrow-\frac{i}{\sqrt{2}},\\
# &\{26,7\}\rightarrow-\frac{i}{\sqrt{6}},\{26,13\}\rightarrow-\frac{i}{\sqrt{6}},\{26,16\}\rightarrow\frac{i}{\sqrt{6}},\{26,19\}\rightarrow\frac{i}{\sqrt{6}},\{26,25\}\rightarrow\frac{i}{\sqrt{6}},\{26,28\}\rightarrow-\frac{i}{\sqrt{6}},\\
# &\{27,47\}\rightarrow\frac{i}{\sqrt{2}},\{27,59\}\rightarrow-\frac{i}{\sqrt{2}},\{28,39\}\rightarrow-\frac{i}{\sqrt{6}},\{28,45\}\rightarrow-\frac{i}{\sqrt{6}},\{28,48\}\rightarrow\frac{i}{\sqrt{6}},\{28,51\}\rightarrow\frac{i}{\sqrt{6}},\\
# &\{28,57\}\rightarrow\frac{i}{\sqrt{6}},\{28,60\}\rightarrow-\frac{i}{\sqrt{6}},\{29,5\}\rightarrow\frac{i}{\sqrt{6}},\{29,8\}\rightarrow-\frac{i}{\sqrt{6}},\{29,14\}\rightarrow-\frac{i}{\sqrt{6}},\{29,17\}\rightarrow-\frac{i}{\sqrt{6}},\\
# &\{29,20\}\rightarrow\frac{i}{\sqrt{6}},\{29,26\}\rightarrow\frac{i}{\sqrt{6}},\{30,6\}\rightarrow\frac{i}{\sqrt{2}},\{30,18\}\rightarrow-\frac{i}{\sqrt{2}},\{31,37\}\rightarrow\frac{i}{\sqrt{6}},\{31,40\}\rightarrow-\frac{i}{\sqrt{6}},\\
# &\{31,46\}\rightarrow-\frac{i}{\sqrt{6}},\{31,49\}\rightarrow-\frac{i}{\sqrt{6}},\{31,52\}\rightarrow\frac{i}{\sqrt{6}},\{31,58\}\rightarrow\frac{i}{\sqrt{6}},\{32,38\}\rightarrow\frac{i}{\sqrt{2}},\{32,50\}\rightarrow-\frac{i}{\sqrt{2}},\\
# &\{33,23\}\rightarrow\frac{1}{\sqrt{6}},\{33,29\}\rightarrow\frac{1}{\sqrt{6}},\{33,32\}\rightarrow\sqrt{\frac{2}{3}},\{34,21\}\rightarrow-\sqrt{\frac{2}{3}},\{34,24\}\rightarrow-\frac{1}{\sqrt{6}},\{34,30\}\rightarrow-\frac{1}{\sqrt{6}},\\
# &\{35,7\}\rightarrow-\frac{1}{3\sqrt{2}},\{35,13\}\rightarrow-\frac{1}{3\sqrt{2}},\{35,16\}\rightarrow-\frac{\sqrt{2}}{3},\{35,19\}\rightarrow-\frac{1}{3\sqrt{2}},\{35,25\}\rightarrow-\frac{1}{3\sqrt{2}},\{35,28\}\rightarrow-\frac{\sqrt{2}}{3},\\
# &\{35,55\}\rightarrow\frac{1}{3\sqrt{2}},\{35,61\}\rightarrow\frac{1}{3\sqrt{2}},\{35,64\}\rightarrow\frac{\sqrt{2}}{3},\{36,5\}\rightarrow\frac{\sqrt{2}}{3},\{36,8\}\rightarrow\frac{1}{3\sqrt{2}},\{36,14\}\rightarrow\frac{1}{3\sqrt{2}},\\
# &\{36,17\}\rightarrow\frac{\sqrt{2}}{3},\{36,20\}\rightarrow\frac{1}{3\sqrt{2}},\{36,26\}\rightarrow\frac{1}{3\sqrt{2}},\{36,53\}\rightarrow-\frac{\sqrt{2}}{3},\{36,56\}\rightarrow-\frac{1}{3\sqrt{2}},\{36,62\}\rightarrow-\frac{1}{3\sqrt{2}},\\
# &\{37,3\}\rightarrow\frac{1}{3\sqrt{2}},\{37,9\}\rightarrow\frac{1}{3\sqrt{2}},\{37,12\}\rightarrow\frac{\sqrt{2}}{3},\{37,39\}\rightarrow-\frac{1}{3\sqrt{2}},\{37,45\}\rightarrow-\frac{1}{3\sqrt{2}},\{37,48\}\rightarrow-\frac{\sqrt{2}}{3},\\
# &\{37,51\}\rightarrow-\frac{1}{3\sqrt{2}},\{37,57\}\rightarrow-\frac{1}{3\sqrt{2}},\{37,60\}\rightarrow-\frac{\sqrt{2}}{3},\{38,1\}\rightarrow-\frac{\sqrt{2}}{3},\{38,4\}\rightarrow-\frac{1}{3\sqrt{2}},\{38,10\}\rightarrow-\frac{1}{3\sqrt{2}},\\
# &\{38,37\}\rightarrow\frac{\sqrt{2}}{3},\{38,40\}\rightarrow\frac{1}{3\sqrt{2}},\{38,46\}\rightarrow\frac{1}{3\sqrt{2}},\{38,49\}\rightarrow\frac{\sqrt{2}}{3},\{38,52\}\rightarrow\frac{1}{3\sqrt{2}},\{38,58\}\rightarrow\frac{1}{3\sqrt{2}},\\
# &\{39,35\}\rightarrow\frac{1}{\sqrt{6}},\{39,41\}\rightarrow\frac{1}{\sqrt{6}},\{39,44\}\rightarrow\sqrt{\frac{2}{3}},\{40,33\}\rightarrow-\sqrt{\frac{2}{3}},\{40,36\}\rightarrow-\frac{1}{\sqrt{6}},\{40,42\}\rightarrow-\frac{1}{\sqrt{6}},\\
# &\{41,23\}\rightarrow\frac{i}{\sqrt{2}},\{41,29\}\rightarrow-\frac{i}{\sqrt{2}},\{42,24\}\rightarrow\frac{i}{\sqrt{2}},\{42,30\}\rightarrow-\frac{i}{\sqrt{2}},\{43,7\}\rightarrow-\frac{i}{\sqrt{6}},\{43,13\}\rightarrow\frac{i}{\sqrt{6}},\\
# &\{43,19\}\rightarrow-\frac{i}{\sqrt{6}},\{43,25\}\rightarrow\frac{i}{\sqrt{6}},\{43,55\}\rightarrow\frac{i}{\sqrt{6}},\{43,61\}\rightarrow-\frac{i}{\sqrt{6}},\{44,8\}\rightarrow-\frac{i}{\sqrt{6}},\{44,14\}\rightarrow\frac{i}{\sqrt{6}},\\
# &\{44,20\}\rightarrow-\frac{i}{\sqrt{6}},\{44,26\}\rightarrow\frac{i}{\sqrt{6}},\{44,56\}\rightarrow\frac{i}{\sqrt{6}},\{44,62\}\rightarrow-\frac{i}{\sqrt{6}},\{45,3\}\rightarrow\frac{i}{\sqrt{6}},\{45,9\}\rightarrow-\frac{i}{\sqrt{6}},\\
# &\{45,39\}\rightarrow-\frac{i}{\sqrt{6}},\{45,45\}\rightarrow\frac{i}{\sqrt{6}},\{45,51\}\rightarrow-\frac{i}{\sqrt{6}},\{45,57\}\rightarrow\frac{i}{\sqrt{6}},\{46,4\}\rightarrow\frac{i}{\sqrt{6}},\{46,10\}\rightarrow-\frac{i}{\sqrt{6}},\\
# &\{46,40\}\rightarrow-\frac{i}{\sqrt{6}},\{46,46\}\rightarrow\frac{i}{\sqrt{6}},\{46,52\}\rightarrow-\frac{i}{\sqrt{6}},\{46,58\}\rightarrow\frac{i}{\sqrt{6}},\{47,35\}\rightarrow\frac{i}{\sqrt{2}},\{47,41\}\rightarrow-\frac{i}{\sqrt{2}},\\
# &\{48,36\}\rightarrow\frac{i}{\sqrt{2}},\{48,42\}\rightarrow-\frac{i}{\sqrt{2}},\{49,31\}\rightarrow 1,\{50,23\}\rightarrow-\frac{1}{\sqrt{3}},\{50,29\}\rightarrow-\frac{1}{\sqrt{3}},\{50,32\}\rightarrow\frac{1}{\sqrt{3}},\\
# &\{51,15\}\rightarrow-\frac{1}{\sqrt{3}},\{51,27\}\rightarrow-\frac{1}{\sqrt{3}},\{51,63\}\rightarrow\frac{1}{\sqrt{3}},\{52,7\}\rightarrow\frac{1}{3},\{52,13\}\rightarrow\frac{1}{3},\{52,16\}\rightarrow-\frac{1}{3},\\
# &\{52,19\}\rightarrow\frac{1}{3},\{52,25\}\rightarrow\frac{1}{3},\{52,28\}\rightarrow-\frac{1}{3},\{52,55\}\rightarrow-\frac{1}{3},\{52,61\}\rightarrow-\frac{1}{3},\{52,64\}\rightarrow\frac{1}{3},\\
# &\{53,11\}\rightarrow\frac{1}{\sqrt{3}},\{53,47\}\rightarrow-\frac{1}{\sqrt{3}},\{53,59\}\rightarrow-\frac{1}{\sqrt{3}},\{54,3\}\rightarrow-\frac{1}{3},\{54,9\}\rightarrow-\frac{1}{3},\{54,12\}\rightarrow\frac{1}{3},\\
# &\{54,39\}\rightarrow\frac{1}{3},\{54,45\}\rightarrow\frac{1}{3},\{54,48\}\rightarrow-\frac{1}{3},\{54,51\}\rightarrow\frac{1}{3},\{54,57\}\rightarrow\frac{1}{3},\{54,60\}\rightarrow-\frac{1}{3},\\
# &\{55,43\}\rightarrow 1,\{56,35\}\rightarrow-\frac{1}{\sqrt{3}},\{56,41\}\rightarrow-\frac{1}{\sqrt{3}},\{56,44\}\rightarrow\frac{1}{\sqrt{3}},\{57,21\}\rightarrow\frac{1}{\sqrt{3}},\{57,24\}\rightarrow-\frac{1}{\sqrt{3}},\\
# &\{57,30\}\rightarrow-\frac{1}{\sqrt{3}},\{58,22\}\rightarrow 1,\{59,5\}\rightarrow-\frac{1}{3},\{59,8\}\rightarrow\frac{1}{3},\{59,14\}\rightarrow\frac{1}{3},\{59,17\}\rightarrow-\frac{1}{3},\\
# &\{59,20\}\rightarrow\frac{1}{3},\{59,26\}\rightarrow\frac{1}{3},\{59,53\}\rightarrow\frac{1}{3},\{59,56\}\rightarrow-\frac{1}{3},\{59,62\}\rightarrow-\frac{1}{3},\{60,6\}\rightarrow-\frac{1}{\sqrt{3}},\\
# &\{60,18\}\rightarrow-\frac{1}{\sqrt{3}},\{60,54\}\rightarrow\frac{1}{\sqrt{3}},\{61,1\}\rightarrow\frac{1}{3},\{61,4\}\rightarrow-\frac{1}{3},\{61,10\}\rightarrow-\frac{1}{3},\{61,37\}\rightarrow-\frac{1}{3},\\
# &\{61,40\}\rightarrow\frac{1}{3},\{61,46\}\rightarrow\frac{1}{3},\{61,49\}\rightarrow-\frac{1}{3},\{61,52\}\rightarrow\frac{1}{3},\{61,58\}\rightarrow\frac{1}{3},\{62,2\}\rightarrow\frac{1}{\sqrt{3}},\\
# &\{62,38\}\rightarrow-\frac{1}{\sqrt{3}},\{62,50\}\rightarrow-\frac{1}{\sqrt{3}},\{63,33\}\rightarrow\frac{1}{\sqrt{3}},\{63,36\}\rightarrow-\frac{1}{\sqrt{3}},\{63,42\}\rightarrow-\frac{1}{\sqrt{3}},\{64,34\}\rightarrow 1.
# \end{align*}
# ```
